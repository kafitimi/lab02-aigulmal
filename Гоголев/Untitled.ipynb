# %%
from PIL import Image
import numpy as np
img = Image.open('darwin.jpg')
img.load()
print(img.size)
print(img.mode)
data = img.getdata()
print(data[0])
a = np.array(data, dtype=np.uint8)
# Out:
# (3000, 3667)
# L
# 5

# %%
a.shape
# Out:
# (11001000,)

# %%
a = a.reshape(3667,3000)

# %%
Image.fromarray(a)

# %% [markdown]
# Image.fromarray(a)

# %%
b=np.zeros((3667,3000))

# %%
x = a[900:1000,900:1100]

# %%
Image.fromarray(x)
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x4B96FF0>

# %%
y = np.zeros((x.shape), dtype = np.uint8)

# %%
Image.fromarray(y)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x4B84170>

# %%
def blur(x, r = 6):
    y=np.zeros(x.shape, dtype = np.uint8)
    for i in range(0,x.shape[0]):
        for j in range(0,x.shape[1]):
            #s=0
            #c=0
            #for dx in range(-r,r+1):
            #    for dy in range(-r,r+1):
            #        if i+dx>=0 and i+dx < x.shape[0] and j+dy>=0 and j+dy < x.shape[1]:
            #            s=s+x[i+dx,j+dy]
            #            c+=1
            y[i][j]=np.average(x[max(i-r,0):min(i+r+1,x.shape[0]-1),\
                                 max(j-r,0):min(j+r+1,x.shape[1]-1)])
    return y

# %%
Image.fromarray(blur(x,10))
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x426BC10>

# %%
Image.fromarray(blur(x,10))
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x426BD30>
