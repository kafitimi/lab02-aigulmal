# %%
from PIL import Image
import numpy as np
img = Image.open('darwin.jpg')
img.load()
print(img.size)
print(img.mode)
data = img.getdata()
print(data[0])
a = np.array(data, dtype=np.uint8)
# Out:
# (3000, 3667)
# L
# 5

# %%
print(data[30])
# Out:
# 113

# %%
type(data)
# Out:
# ImagingCore

# %%
a.shape
# Out:
# (11001000,)

# %%
a = a.reshape(3667,3000)

# %%
a = a.reshape(3000,3667)

# %%
a[200][1600]
# Out:
# 0

# %%
a.shape
# Out:
# (3000, 3667)

# %%
a[1600,200]
# Out:
# 4

# %%
a = a.reshape(3667,3000)

# %%
Image.fromarray(a)

# %%
img2 = Image.fromarray(a)

# %%
img2

# %%
v=np.zeros?

# %%
b=np.zeros?

# %%
b=np.zeros((3667,3000))

# %%
x = a[900:1100,900:1100]

# %%
x
# Out:
# array([[253, 184,  46, ...,   0,  49, 132],
#        [255, 141,  19, ...,   7, 198, 255],
#        [252, 196,  40, ...,  48, 229, 248],
#        ...,
#        [  0,   1,   2, ..., 249, 255, 255],
#        [  3,   2,   0, ..., 255, 249, 251],
#        [  0,   0,   4, ..., 255, 248, 255]], dtype=uint8)

# %%
Image.fromarray(x)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x4B74B30>

# %%
y = np.zeros(x.shape, dtype=np.uint8)

# %%
Image.fromarray(y)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x50A9430>

# %%
r = 6
for i in range (r,200-r):
    for j in range(r,200-r):
        s=0
        for dx in range (-r,r+1):
            for dy in range (-r,r+1):
                s=s+x[i+dx,j+dy]
        y[i][j]=int(s/(2*r+1)**2)

# %%
Image.fromarray(y)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x50CA590>

# %%
Image.fromarray(x)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x50CAC30>

# %%
def blur(x,r = 6):
    y = np.zeros(x.shape,dtype=np.uint8)
    for i in range (0,x.shape[0]):
        for j in range(0,x.shape[1]):
    #        s=0
    #        c=0
    #        for dx in range (-r,r+1):
    #            for dy in range (-r,r+1):
    #                if i+dx>=0 and i+dx <x.shape[0] and j+dy>=0 and j+dy <x.shape[1]:
    #                    s = s + x[i+dx, j+dy]
    #                    c+=1
            y[i][j]=np.average(x[max(i-r,0):min(i+r+1, x.shape[0]-1) ,\
                                 max(j-r,0):min(j+r+1, x.shape[0]-1)])
    return y

# %%
Image.fromarray(blur(x,6))
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x50CC750>

# %%
p =np.array([[1,2,3],[4,5,6]])

# %%
np.average(p)
# Out:
# 3.5
